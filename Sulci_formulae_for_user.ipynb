# %%
data_file_name = '/home/amachlou/Documents/GitHub/sulcal_neuroanatomy/sulcal_neuroanatomy.py'
from sulcal_neuroanatomy import *

# %%
all_subs_and_hems = making_tables_of_each_sub_and_hem(All_probabilities, subject_ids, hemispheres)
All_subject_and_hemisphere_sets = making_sets_of_relative_sulci_per_hemisphere_and_subject(all_subs_and_hems, sulci_names)

# %%
import sulcal_neuroanatomy as sn
import importlib

importlib.reload(sn)
# Out:
# <module 'sulcal_neuroanatomy' from '/home/amachlou/Documents/GitHub/sulcal_neuroanatomy/sulcal_neuroanatomy.py'>

# %% [markdown]
# ## Sulci analysed (20)

# %% [markdown]
# ##### Precentral sulcus, Marginal sulcus, Intraparietal sulcus, Collateral sulcus (posterior), Collateral sulcus (anterior), Frontal middle sulcus, Temporal transverse sulcus, Inferior temporal sulcus, Superior temporal sulcus, Subparietal sulcus, Superior frontal sulcus, Calcarine sulcus, Postcentral sulcus, Inferior frontal sulcus, Pericallosal sulcus, Lateral occipit(o-temporal) sulcus, Suborbital sulcus, Sulcus intermedius primus of Jensen, Occipital middle and lunatus sulcus, Superior occipital sulcus

# %% [markdown]
# ### Precentral Sulcus

# %%
PrCS_check_left = sn.prcs_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
PrCS_check_right = sn.prcs_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

PrCS_prob_left = sn.calculating_prob_of_PrCS_found(subject_ids, PrCS_check_left, 'Precentral_sulcus')
PrCS_prob_right = sn.calculating_prob_of_PrCS_found(subject_ids, PrCS_check_right, 'Precentral_sulcus')

# %%
print(PrCS_prob_left, PrCS_prob_right)
# Out:
# (262, 572, 0.458041958041958) (245, 572, 0.42832167832167833)

# %%
PrCS_left_accuracy = sn.PrCS_formula_accuracy_check(subject_ids, PrCS_check_left)
PrCS_right_accuracy = sn.PrCS_formula_accuracy_check(subject_ids, PrCS_check_right)

# %%
PrCS_left_accuracy
# Out:
# ({102715: 6,
#   102816: 5,
#   103111: 6,
#   103212: 6,
#   103414: 4,
#   104416: 7,
#   104820: 6,
#   105115: 5,
#   106319: 5,
#   106521: 7,
#   107018: 6,
#   108525: 7,
#   108828: 5,
#   109123: 6,
#   110411: 7,
#   111312: 6,
#   111413: 7,
#   112112: 6,
#   112819: 6,
#   113619: 5,
#   113821: 6,
#   113922: 3,
#   114419: 6,
#   115017: 7,
#   116524: 7,
#   117324: 6,
#   118124: 7,
#   120717: 4,
#   121315: 6,
#   121416: 6,
#   121618: 5,
#   122620: 5,
#   123117: 7,
#   123420: 5,
#   123925: 6,
#   125525: 7,
#   126931: 5,
#   127630: 6,
#   127832: 6,
#   127933: 7,
#   131217: 7,
#   131419: 5,
#   131621: 7,
#   131823: 5,
#   133625: 6,
#   134021: 6,
#   134324: 6,
#   135124: 6,
#   135225: 6,
#   135528: 6,
#   137431: 6,
#   138534: 7,
#   139435: 6,
#   139839: 6,
#   140420: 5,
#   140925: 6,
#   144226: 7,
#   145632: 7,
#   150524: 5,
#   150625: 5,
#   150726: 7,
#   151223: 7,
#   151425: 6,
#   151930: 6,
#   152225: 6,
#   153025: 5,
# ...

# %%
PrCS_right_accuracy
# Out:
# ({103111: 6,
#   103212: 3,
#   103515: 6,
#   104012: 6,
#   105115: 5,
#   105216: 5,
#   105620: 5,
#   106319: 5,
#   106521: 5,
#   108121: 3,
#   108323: 5,
#   109123: 5,
#   110411: 5,
#   111413: 4,
#   111716: 3,
#   113215: 3,
#   113619: 5,
#   113922: 6,
#   114419: 4,
#   117122: 5,
#   117324: 4,
#   117930: 6,
#   118124: 4,
#   120717: 5,
#   123420: 5,
#   124220: 6,
#   124826: 5,
#   126931: 5,
#   127832: 5,
#   127933: 5,
#   131722: 3,
#   131823: 6,
#   133019: 5,
#   133625: 5,
#   133827: 5,
#   134324: 6,
#   135124: 4,
#   135528: 4,
#   136833: 3,
#   137431: 4,
#   139839: 6,
#   140420: 5,
#   140925: 4,
#   141826: 6,
#   142424: 5,
#   144226: 6,
#   145632: 4,
#   148133: 4,
#   148941: 6,
#   150524: 6,
#   151425: 5,
#   151627: 6,
#   152225: 7,
#   153025: 7,
#   153429: 5,
#   153833: 5,
#   154431: 6,
#   154734: 3,
#   154936: 4,
#   155231: 6,
#   156637: 5,
#   157336: 5,
#   158540: 5,
#   158843: 4,
#   161327: 5,
#   162733: 6,
# ...

# %% [markdown]
# ### Marginal Sulcus

# %%
marginal_check_left = sn.marginal_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
marginal_check_right = sn.marginal_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

marginal_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, marginal_check_left, 'Marginal_sulcus', 'S_cingul-Marginalis')
marginal_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, marginal_check_right, 'Marginal_sulcus', 'S_cingul-Marginalis')

# %%
marginal_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, marginal_check_left, 'Marginal_sulcus', 'S_cingul-Marginalis')
marginal_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, marginal_check_right, 'Marginal_sulcus', 'S_cingul-Marginalis')

# %%
print(marginal_prob_left, marginal_prob_right)
# Out:
# (570, 572, 0.9965034965034965) (572, 572, 1.0)

# %%
marginal_left_accuracy = sn.accuracy_check(subject_ids, marginal_check_left, 'S_cingul-Marginalis')
marginal_right_accuracy = sn.accuracy_check(subject_ids, marginal_check_right, 'S_cingul-Marginalis')

# %%
marginal_left_accuracy
# Out:
# ({102715: 9,
#   102816: 11,
#   103111: 11,
#   103212: 11,
#   103414: 9,
#   103515: 7,
#   103818: 8,
#   104012: 9,
#   104416: 13,
#   104820: 6,
#   105014: 10,
#   105115: 11,
#   105216: 10,
#   105620: 12,
#   106016: 12,
#   106319: 8,
#   106521: 8,
#   107018: 9,
#   107321: 12,
#   107422: 9,
#   108121: 9,
#   108323: 12,
#   108525: 10,
#   108828: 10,
#   109123: 9,
#   109325: 8,
#   110411: 14,
#   111009: 9,
#   111312: 12,
#   111413: 9,
#   111716: 12,
#   112112: 11,
#   112819: 12,
#   113215: 14,
#   113619: 13,
#   113821: 9,
#   113922: 9,
#   114419: 8,
#   114924: 3,
#   115017: 8,
#   115320: 10,
#   116120: 10,
#   116524: 9,
#   117122: 11,
#   117324: 10,
#   117930: 12,
#   118124: 11,
#   118225: 10,
#   120717: 12,
#   121315: 10,
#   121416: 10,
#   121618: 8,
#   122317: 10,
#   122620: 13,
#   122822: 12,
#   123117: 7,
#   123420: 11,
#   123925: 11,
#   124220: 10,
#   124422: 12,
#   124826: 10,
#   125222: 10,
#   125424: 6,
#   125525: 9,
# ...

# %%
marginal_right_accuracy
# Out:
# ({102715: 8,
#   102816: 12,
#   103111: 12,
#   103212: 11,
#   103414: 9,
#   103515: 10,
#   103818: 10,
#   104012: 11,
#   104416: 11,
#   104820: 8,
#   105014: 13,
#   105115: 11,
#   105216: 10,
#   105620: 11,
#   106016: 12,
#   106319: 13,
#   106521: 11,
#   107018: 12,
#   107321: 12,
#   107422: 8,
#   108121: 15,
#   108323: 9,
#   108525: 12,
#   108828: 10,
#   109123: 11,
#   109325: 9,
#   110411: 11,
#   111009: 9,
#   111312: 8,
#   111413: 10,
#   111716: 11,
#   112112: 12,
#   112819: 12,
#   113215: 14,
#   113619: 15,
#   113821: 13,
#   113922: 10,
#   114419: 12,
#   114924: 10,
#   115017: 7,
#   115320: 9,
#   116120: 11,
#   116524: 10,
#   117122: 10,
#   117324: 13,
#   117930: 13,
#   118124: 12,
#   118225: 10,
#   120717: 12,
#   121315: 13,
#   121416: 11,
#   121618: 15,
#   122317: 9,
#   122620: 10,
#   122822: 13,
#   123117: 10,
#   123420: 12,
#   123925: 13,
#   124220: 11,
#   124422: 11,
#   124826: 9,
#   125222: 12,
#   125424: 10,
# ...

# %% [markdown]
# ### Intraparietal Sulcus

# %%
ips_check_left = sn.ips_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
ips_check_right = sn.ips_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
ips_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, ips_check_left, 'Intraparietal_sulcus', 'S_intrapariet_and_P_trans')
ips_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, ips_check_right, 'Intraparietal_sulcus', 'S_intrapariet_and_P_trans')

# %%
print(ips_prob_left, ips_prob_right)
# Out:
# (32, 572, 0.055944055944055944) (8, 572, 0.013986013986013986)

# %%
ips_left_accuracy = sn.accuracy_check(subject_ids, ips_check_left, 'S_intrapariet_and_P_trans')
ips_right_accuracy = sn.accuracy_check(subject_ids, ips_check_right, 'S_intrapariet_and_P_trans')

# %%
ips_left_accuracy
# Out:
# ({109123: 1,
#   112819: 1,
#   124826: 1,
#   132118: 1,
#   146533: 1,
#   161630: 1,
#   168341: 3,
#   169343: 1,
#   173536: 1,
#   173738: 1,
#   176037: 1,
#   182739: 1,
#   185442: 1,
#   188145: 2,
#   201414: 1,
#   204218: 1,
#   204521: 1,
#   207123: 1,
#   209329: 1,
#   250427: 1,
#   251833: 1,
#   255639: 1,
#   280941: 1,
#   304020: 2,
#   436845: 3,
#   459453: 1,
#   541640: 1,
#   541943: 2,
#   566454: 1,
#   683256: 2,
#   690152: 1,
#   861456: 1},
#  26,
#  0.8125)

# %%
ips_right_accuracy
# Out:
# ({111312: 1,
#   144226: 1,
#   153833: 1,
#   168947: 2,
#   198350: 1,
#   211720: 1,
#   280739: 1,
#   732243: 2},
#  6,
#  0.75)

# %% [markdown]
# ### Collateral Transverse Sulcus_Posterior

# %%
collat_transv_post_check_left = sn.coll_transv_post_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
collat_transv_post_check_right = sn.coll_transv_post_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
collat_transv_post_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, collat_transv_post_check_left, 'Posterior_collateral_transverse_sulcus', 'S_collat_transv_post')
collat_transv_post_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, collat_transv_post_check_right, 'Posterior_collateral_transverse_sulcus', 'S_collat_transv_post')

# %%
print(collat_transv_post_prob_left, collat_transv_post_prob_right)
# Out:
# (213, 572, 0.3723776223776224) (264, 572, 0.46153846153846156)

# %%
collat_transv_post_left_accuracy = sn.accuracy_check(subject_ids, collat_transv_post_check_left, 'S_collat_transv_post')
collat_transv_post_right_accuracy = sn.accuracy_check(subject_ids, collat_transv_post_check_right, 'S_collat_transv_post')

# %%
collat_transv_post_left_accuracy
# Out:
# ({102816: 1,
#   103111: 1,
#   103818: 1,
#   105115: 1,
#   105216: 1,
#   105620: 1,
#   108525: 1,
#   109325: 2,
#   110411: 1,
#   111009: 1,
#   112112: 1,
#   113215: 1,
#   113821: 1,
#   114419: 1,
#   114924: 1,
#   115017: 1,
#   116120: 1,
#   116524: 1,
#   117930: 1,
#   121315: 1,
#   121618: 1,
#   123117: 1,
#   123925: 1,
#   124422: 1,
#   125222: 1,
#   125424: 1,
#   127630: 1,
#   127933: 1,
#   130619: 1,
#   131924: 1,
#   132118: 1,
#   137027: 1,
#   137431: 1,
#   138534: 1,
#   143325: 2,
#   144226: 1,
#   146533: 1,
#   148133: 1,
#   150524: 1,
#   150625: 1,
#   150726: 1,
#   151627: 1,
#   151728: 1,
#   151930: 1,
#   152831: 1,
#   153025: 1,
#   153227: 1,
#   154532: 1,
#   154936: 1,
#   156637: 1,
#   158136: 1,
#   159239: 1,
#   163331: 1,
#   165032: 1,
#   167238: 1,
#   168341: 1,
#   168947: 1,
#   169141: 1,
#   169343: 1,
#   169747: 1,
#   170934: 2,
#   171330: 1,
#   172029: 1,
#   172938: 1,
#   173536: 1,
#   175237: 1,
# ...

# %%
collat_transv_post_right_accuracy
# Out:
# ({103111: 1,
#   103212: 1,
#   103515: 2,
#   105620: 1,
#   106319: 1,
#   106521: 1,
#   108525: 1,
#   108828: 1,
#   109325: 1,
#   110411: 1,
#   111009: 1,
#   111716: 1,
#   114419: 1,
#   114924: 2,
#   116120: 1,
#   117930: 1,
#   118225: 1,
#   121416: 1,
#   121618: 1,
#   123117: 2,
#   123420: 1,
#   124826: 2,
#   125222: 1,
#   126931: 1,
#   127630: 1,
#   127832: 1,
#   127933: 1,
#   131621: 1,
#   131823: 1,
#   133827: 1,
#   135932: 1,
#   136227: 1,
#   137027: 2,
#   138534: 2,
#   140420: 1,
#   140925: 1,
#   142424: 2,
#   144226: 1,
#   145531: 1,
#   146533: 1,
#   148941: 1,
#   150625: 1,
#   150726: 1,
#   151526: 1,
#   151627: 1,
#   151728: 2,
#   152831: 1,
#   153126: 1,
#   153429: 1,
#   154431: 1,
#   154532: 2,
#   154734: 1,
#   154835: 1,
#   154936: 1,
#   155231: 1,
#   155635: 1,
#   156031: 1,
#   156233: 2,
#   156637: 1,
#   157336: 1,
#   158136: 1,
#   161327: 2,
#   161731: 1,
#   162228: 1,
#   162329: 1,
#   162733: 1,
# ...

# %% [markdown]
# ### Collateral Transverse Sulcus_Anterior

# %%
collat_transv_ant_check_left = sn.coll_transv_ant_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
collat_transv_ant_check_right = sn.coll_transv_ant_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
collat_transv_ant_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, collat_transv_ant_check_left, 'Anterior_collateral_transverse_sulcus', 'S_collat_transv_ant')
collat_transv_ant_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, collat_transv_ant_check_right, 'Anterior_collateral_transverse_sulcus', 'S_collat_transv_ant')

# %%
print(collat_transv_ant_prob_left, collat_transv_ant_prob_right)
# Out:
# (170, 572, 0.2972027972027972) (154, 572, 0.2692307692307692)

# %%
collat_transv_ant_left_accuracy = sn.accuracy_check(subject_ids, collat_transv_ant_check_left, 'S_collat_transv_ant')
collat_transv_ant_right_accuracy = sn.accuracy_check(subject_ids, collat_transv_ant_check_right, 'S_collat_transv_ant')

# %%
collat_transv_ant_left_accuracy
# Out:
# ({102715: 1,
#   103212: 1,
#   103414: 2,
#   106319: 2,
#   109123: 1,
#   111413: 1,
#   112819: 1,
#   114419: 1,
#   115017: 1,
#   116120: 1,
#   116524: 2,
#   117930: 2,
#   118225: 1,
#   121315: 1,
#   122317: 2,
#   124826: 1,
#   127832: 3,
#   130619: 1,
#   131722: 1,
#   133019: 1,
#   133625: 1,
#   133827: 1,
#   135124: 1,
#   135528: 1,
#   135932: 2,
#   138534: 2,
#   139435: 1,
#   148941: 1,
#   150524: 1,
#   151223: 1,
#   151627: 2,
#   152831: 1,
#   154431: 1,
#   154835: 1,
#   154936: 1,
#   156233: 1,
#   156637: 1,
#   157437: 1,
#   158035: 1,
#   158136: 1,
#   158843: 1,
#   159239: 2,
#   161327: 1,
#   162329: 1,
#   162733: 1,
#   163129: 1,
#   168947: 2,
#   169343: 1,
#   169747: 1,
#   171330: 1,
#   173132: 1,
#   173536: 1,
#   174437: 2,
#   175035: 1,
#   175237: 1,
#   175742: 2,
#   176542: 1,
#   176744: 2,
#   177645: 3,
#   178748: 1,
#   179548: 1,
#   181131: 1,
#   183034: 1,
#   185139: 1,
#   185947: 1,
#   187547: 3,
# ...

# %%
collat_transv_ant_right_accuracy
# Out:
# ({103111: 1,
#   103212: 1,
#   103414: 1,
#   105014: 2,
#   108323: 1,
#   109123: 1,
#   113821: 1,
#   114419: 1,
#   117930: 1,
#   118225: 1,
#   121315: 1,
#   123420: 1,
#   127630: 1,
#   127832: 4,
#   130619: 2,
#   130922: 1,
#   131217: 1,
#   131419: 1,
#   131823: 1,
#   133019: 1,
#   133827: 1,
#   134324: 1,
#   135932: 4,
#   136833: 1,
#   137027: 1,
#   137431: 1,
#   139435: 1,
#   140925: 1,
#   141826: 1,
#   148133: 1,
#   148941: 1,
#   151223: 1,
#   151425: 1,
#   151627: 1,
#   154431: 1,
#   154835: 1,
#   156031: 1,
#   158035: 1,
#   162733: 1,
#   167440: 1,
#   167743: 1,
#   169343: 1,
#   169747: 3,
#   171330: 1,
#   171431: 1,
#   172130: 1,
#   172534: 3,
#   173536: 1,
#   177746: 1,
#   178142: 1,
#   178748: 1,
#   182032: 1,
#   182739: 1,
#   183034: 1,
#   185038: 1,
#   185947: 1,
#   186141: 1,
#   191336: 1,
#   192540: 1,
#   195950: 1,
#   197550: 1,
#   198855: 1,
#   199655: 1,
#   199958: 1,
#   200614: 1,
#   201111: 1,
# ...

# %% [markdown]
# ### Frontal Middle Sulcus

# %%
fms_check_left = sn.fms_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
fms_check_right = sn.fms_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
fms_prob_left = sn,calculating_prob_of_sulcus_found(subject_ids, fms_check_left, 'Frontal_middle_sulcus', 'S_front_middle')
fms_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, fms_check_right, 'Frontal_middle_sulcus', 'S_front_middle')

# %%
print(fms_prob_left, fms_prob_right)
# Out:
# (<module 'sulcal_neuroanatomy' from '/home/amachlou/Documents/GitHub/sulcal_neuroanatomy/sulcal_neuroanatomy.py'>, (176, 572, 0.3076923076923077)) (148, 572, 0.25874125874125875)

# %%
fms_left_accuracy = sn.accuracy_check(subject_ids, fms_check_left, 'S_front_middle')
fms_right_accuracy = sn.accuracy_check(subject_ids, fms_check_right, 'S_front_middle')

# %%
fms_left_accuracy
# Out:
# ({102715: 3,
#   103111: 3,
#   105014: 2,
#   105115: 2,
#   105216: 2,
#   105620: 2,
#   106319: 1,
#   106521: 3,
#   108121: 2,
#   108525: 3,
#   108828: 1,
#   109325: 3,
#   111716: 3,
#   112112: 2,
#   115320: 3,
#   116120: 1,
#   116524: 3,
#   117122: 2,
#   118225: 3,
#   121618: 1,
#   122620: 1,
#   124220: 1,
#   125222: 2,
#   125424: 1,
#   125525: 3,
#   127630: 3,
#   131621: 3,
#   131722: 3,
#   131924: 2,
#   132118: 3,
#   134728: 2,
#   135124: 2,
#   135932: 3,
#   136227: 2,
#   142424: 2,
#   145531: 2,
#   145632: 4,
#   150625: 1,
#   150726: 4,
#   151425: 3,
#   152831: 3,
#   153833: 4,
#   154936: 1,
#   155635: 3,
#   157336: 3,
#   158035: 4,
#   158136: 2,
#   158540: 1,
#   158843: 1,
#   159441: 3,
#   161630: 2,
#   161731: 2,
#   162733: 1,
#   163129: 3,
#   167743: 2,
#   171431: 3,
#   173435: 3,
#   173536: 2,
#   176744: 2,
#   177645: 3,
#   177746: 4,
#   178950: 1,
#   179548: 3,
#   180432: 4,
#   181131: 1,
#   181232: 1,
# ...

# %%
fms_right_accuracy
# Out:
# ({102715: 1,
#   103111: 2,
#   105014: 2,
#   105620: 1,
#   106319: 1,
#   106521: 2,
#   109325: 1,
#   111312: 1,
#   113619: 2,
#   113922: 2,
#   114924: 2,
#   117122: 1,
#   118124: 1,
#   121315: 1,
#   122317: 2,
#   122822: 1,
#   125222: 2,
#   127630: 2,
#   127933: 2,
#   130619: 1,
#   131621: 1,
#   132118: 1,
#   133625: 1,
#   135124: 1,
#   135225: 2,
#   135932: 3,
#   142424: 1,
#   143325: 2,
#   145632: 1,
#   146533: 2,
#   148941: 2,
#   150524: 2,
#   150625: 3,
#   151425: 2,
#   151627: 3,
#   153126: 3,
#   153227: 3,
#   154431: 3,
#   154835: 4,
#   155938: 2,
#   165032: 4,
#   167743: 1,
#   169141: 1,
#   169343: 3,
#   169444: 1,
#   169747: 1,
#   172534: 3,
#   172938: 1,
#   173940: 1,
#   175035: 2,
#   176744: 2,
#   177746: 3,
#   178849: 1,
#   180937: 2,
#   181131: 1,
#   185038: 1,
#   195950: 1,
#   196952: 2,
#   198249: 3,
#   199655: 1,
#   201818: 1,
#   206222: 1,
#   208327: 2,
#   209228: 1,
#   212116: 3,
#   214423: 2,
# ...

# %% [markdown]
# ### Temporal Transverse Sulcus

# %%
tts_check_left = sn.tts_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
tts_check_right = sn.tts_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
tts_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, tts_check_left, 'Temporal_transverse_sulcus', 'S_temporal_transverse')
tts_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, tts_check_right, 'Temporal_transverse_sulcus', 'S_temporal_transverse')

# %%
print(tts_prob_left, tts_prob_right)
# Out:
# (367, 572, 0.6416083916083916) (332, 572, 0.5804195804195804)

# %%
tts_left_accuracy = sn.accuracy_check(subject_ids, tts_check_left, 'S_temporal_transverse')
tts_right_accuracy = sn.accuracy_check(subject_ids, tts_check_right, 'S_temporal_transverse')

# %%
tts_left_accuracy
# Out:
# ({103111: 3,
#   103414: 1,
#   103818: 1,
#   104012: 3,
#   104820: 1,
#   105014: 1,
#   106016: 1,
#   106319: 2,
#   106521: 1,
#   107018: 2,
#   107422: 2,
#   108121: 2,
#   108525: 1,
#   108828: 1,
#   109123: 3,
#   111009: 3,
#   111312: 1,
#   111716: 1,
#   112112: 2,
#   113215: 1,
#   113619: 1,
#   113821: 2,
#   113922: 3,
#   114419: 1,
#   114924: 3,
#   115017: 1,
#   116120: 2,
#   117324: 2,
#   117930: 1,
#   118124: 1,
#   118225: 1,
#   120717: 2,
#   121416: 1,
#   121618: 1,
#   122317: 1,
#   122822: 3,
#   123117: 1,
#   123420: 1,
#   123925: 1,
#   124220: 1,
#   124422: 3,
#   124826: 2,
#   125222: 1,
#   125424: 1,
#   125525: 1,
#   127832: 1,
#   130619: 2,
#   130922: 2,
#   131419: 2,
#   131621: 2,
#   131924: 1,
#   133019: 2,
#   133625: 1,
#   133827: 1,
#   133928: 1,
#   134021: 1,
#   134728: 1,
#   135124: 1,
#   135225: 1,
#   135528: 2,
#   136227: 1,
#   136833: 3,
#   137027: 2,
#   137431: 2,
#   138534: 1,
#   139435: 3,
# ...

# %%
tts_right_accuracy
# Out:
# ({103212: 2,
#   103414: 4,
#   103818: 1,
#   104012: 2,
#   104820: 1,
#   105014: 2,
#   105115: 2,
#   105620: 1,
#   106016: 2,
#   106319: 3,
#   106521: 1,
#   107018: 2,
#   107321: 1,
#   107422: 1,
#   108121: 3,
#   108323: 2,
#   108525: 1,
#   109325: 1,
#   110411: 1,
#   111009: 2,
#   111312: 1,
#   111716: 1,
#   112112: 3,
#   112819: 1,
#   113215: 1,
#   113619: 1,
#   113821: 1,
#   114419: 1,
#   114924: 2,
#   115017: 1,
#   116120: 1,
#   117324: 2,
#   117930: 1,
#   121315: 1,
#   121416: 1,
#   121618: 1,
#   122317: 2,
#   122822: 1,
#   123420: 2,
#   124220: 1,
#   124422: 3,
#   125222: 1,
#   125525: 3,
#   127630: 1,
#   127832: 2,
#   127933: 1,
#   130619: 2,
#   130922: 1,
#   131217: 1,
#   131419: 2,
#   131621: 3,
#   133019: 1,
#   134021: 1,
#   134728: 1,
#   135124: 1,
#   135528: 2,
#   136833: 3,
#   137431: 2,
#   138534: 1,
#   139839: 2,
#   140420: 2,
#   140925: 2,
#   144226: 3,
#   145531: 2,
#   145632: 2,
#   146533: 1,
# ...

# %% [markdown]
# ### Inferior Temporal Sulcus

# %%
its_check_left = sn.its_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
its_check_right = sn.its_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
its_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, its_check_left, 'Inferior_temporal_sulcus', 'S_temporal_inf')
its_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, its_check_right, 'Inferior_temporal_sulcus', 'S_temporal_inf')

# %%
print(its_prob_left, its_prob_right)
# Out:
# (13, 572, 0.022727272727272728) (14, 572, 0.024475524475524476)

# %%
its_left_accuracy = sn.accuracy_check(subject_ids, its_check_left, 'S_temporal_inf')
its_right_accuracy = sn.accuracy_check(subject_ids, its_check_right, 'S_temporal_inf')

# %%
its_left_accuracy
# Out:
# ({126931: 1,
#   154431: 1,
#   187850: 1,
#   198855: 1,
#   211316: 1,
#   211417: 1,
#   211720: 2,
#   212419: 1,
#   561242: 1,
#   579665: 1,
#   592455: 1,
#   865363: 1,
#   965367: 1},
#  12,
#  0.9230769230769231)

# %%
its_right_accuracy
# Out:
# ({104416: 1,
#   123925: 1,
#   124422: 1,
#   167440: 2,
#   199958: 1,
#   207628: 1,
#   540436: 1,
#   561242: 1,
#   565452: 1,
#   583858: 1,
#   685058: 4,
#   825048: 1,
#   826454: 1,
#   861456: 1},
#  12,
#  0.8571428571428571)

# %% [markdown]
# ### Superior Temporal Sulcus

# %%
import sulcal_neuroanatomy as sn
import importlib

importlib.reload(sn)
# Out:
# <module 'sulcal_neuroanatomy' from '/home/amachlou/Documents/GitHub/sulcal_neuroanatomy/sulcal_neuroanatomy.py'>

# %%
sts_check_left = sn.sts_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
sts_check_right = sn.sts_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
sts_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, sts_check_left, 'Superior_temporal_sulcus', 'S_temporal_sup')
sts_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, sts_check_right, 'Superior_temporal_sulcus', 'S_temporal_sup')

# %%
print(sts_prob_left, sts_prob_right)
# Out:
# (86, 572, 0.15034965034965034) (79, 572, 0.1381118881118881)

# %%
sts_left_accuracy = sn.accuracy_check(subject_ids, sts_check_left, 'S_temporal_sup')
sts_right_accuracy = sn.accuracy_check(subject_ids, sts_check_right, 'S_temporal_sup')

# %%
sts_left_accuracy
# Out:
# ({103111: 17,
#   105216: 18,
#   105620: 18,
#   107321: 18,
#   108121: 15,
#   112819: 17,
#   120717: 19,
#   121315: 16,
#   122620: 18,
#   124220: 16,
#   125525: 17,
#   127933: 16,
#   131722: 19,
#   133019: 19,
#   135225: 18,
#   135932: 16,
#   136227: 18,
#   136833: 17,
#   145632: 19,
#   146533: 18,
#   148133: 20,
#   150524: 17,
#   151728: 14,
#   153025: 18,
#   154532: 17,
#   154835: 19,
#   158136: 19,
#   168341: 18,
#   168947: 19,
#   169141: 14,
#   171431: 17,
#   172130: 19,
#   173738: 19,
#   175237: 17,
#   177746: 19,
#   178142: 16,
#   178849: 18,
#   182739: 18,
#   185139: 20,
#   188145: 15,
#   198855: 18,
#   200311: 18,
#   200614: 17,
#   201111: 20,
#   201414: 21,
#   204218: 18,
#   205220: 19,
#   208428: 18,
#   209834: 18,
#   210617: 18,
#   211215: 16,
#   212217: 18,
#   217429: 17,
#   303119: 19,
#   378756: 19,
#   385046: 18,
#   385450: 17,
#   390645: 19,
#   395756: 16,
#   395958: 20,
#   397154: 20,
#   433839: 16,
# ...

# %%
sts_right_accuracy
# Out:
# ({104416: 17,
#   105115: 15,
#   106319: 15,
#   108323: 16,
#   112112: 15,
#   113821: 15,
#   113922: 15,
#   126931: 15,
#   127832: 17,
#   130619: 16,
#   130922: 15,
#   131419: 16,
#   133019: 15,
#   134021: 13,
#   134324: 17,
#   135124: 17,
#   135225: 12,
#   153126: 14,
#   154734: 15,
#   158136: 15,
#   158843: 16,
#   162329: 15,
#   162733: 14,
#   167440: 15,
#   168947: 14,
#   172029: 14,
#   172130: 16,
#   173536: 15,
#   178748: 15,
#   178950: 15,
#   180937: 16,
#   188145: 17,
#   191942: 16,
#   196750: 13,
#   197348: 14,
#   198855: 16,
#   199150: 15,
#   199655: 15,
#   205725: 16,
#   207628: 15,
#   211821: 19,
#   212217: 13,
#   249947: 15,
#   251833: 14,
#   257542: 12,
#   268850: 16,
#   281135: 16,
#   284646: 14,
#   290136: 16,
#   303119: 15,
#   333330: 16,
#   346137: 16,
#   349244: 15,
#   365343: 15,
#   448347: 15,
#   453441: 14,
#   467351: 15,
#   506234: 16,
#   519647: 16,
#   530635: 16,
#   540436: 16,
#   573249: 14,
# ...

# %% [markdown]
# ### Subparietal Sulcus

# %%
subparietal_check_left = sn.subparietal_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
subparietal_check_right = sn.subparietal_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
subparietal_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, subparietal_check_left, 'Subparietal_sulcus', 'S_subparietal')
subparietal_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, subparietal_check_right, 'Subparietal_sulcus', 'S_subparietal')

# %%
print(subparietal_prob_left, subparietal_prob_right)
# Out:
# (37, 572, 0.06468531468531469) (37, 572, 0.06468531468531469)

# %%
subparietal_left_accuracy = sn.accuracy_check(subject_ids, subparietal_check_left, 'S_subparietal')
subparietal_right_accuracy = sn.accuracy_check(subject_ids, subparietal_check_right, 'S_subparietal')

# %%
subparietal_left_accuracy
# Out:
# ({108121: 1,
#   116120: 1,
#   117324: 1,
#   120717: 1,
#   135225: 1,
#   154835: 1,
#   173536: 1,
#   173738: 1,
#   182840: 1,
#   205220: 1,
#   205725: 1,
#   207628: 1,
#   214726: 1,
#   250932: 1,
#   286650: 1,
#   309636: 1,
#   330324: 1,
#   358144: 1,
#   378756: 2,
#   393550: 1,
#   421226: 1,
#   441939: 1,
#   485757: 1,
#   566454: 1,
#   581349: 1,
#   588565: 1,
#   598568: 1,
#   650746: 1,
#   715950: 1,
#   789373: 1,
#   826353: 1,
#   841349: 1,
#   877168: 1,
#   889579: 1,
#   891667: 1,
#   894774: 1,
#   896879: 1},
#  36,
#  0.972972972972973)

# %%
subparietal_right_accuracy
# Out:
# ({103414: 1,
#   103818: 1,
#   109325: 1,
#   116120: 1,
#   118124: 1,
#   120717: 1,
#   124826: 1,
#   132118: 1,
#   150625: 1,
#   155231: 1,
#   165032: 3,
#   169444: 1,
#   171633: 1,
#   190031: 1,
#   200311: 2,
#   211316: 1,
#   236130: 1,
#   280739: 1,
#   281135: 1,
#   285345: 1,
#   356948: 1,
#   366446: 1,
#   385046: 1,
#   441939: 1,
#   485757: 1,
#   581349: 1,
#   664757: 1,
#   742549: 1,
#   761957: 1,
#   773257: 1,
#   779370: 1,
#   789373: 1,
#   792766: 1,
#   814649: 1,
#   816653: 1,
#   835657: 1,
#   957974: 1},
#  35,
#  0.9459459459459459)

# %% [markdown]
# ### Superior Frontal Sulcus

# %%
SFS_check_left = sn.sfs_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
SFS_check_right = sn.sfs_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
SFS_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, SFS_check_left, 'Superior_frontal_sulcus', 'S_front_sup')
SFS_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, SFS_check_right, 'Superior_frontal_sulcus', 'S_front_sup')

# %%
print(SFS_prob_left, SFS_prob_right)
# Out:
# (225, 572, 0.39335664335664333) (112, 572, 0.1958041958041958)

# %%
SFS_left_accuracy = sn.accuracy_check(subject_ids, SFS_check_left, 'S_front_sup')
SFS_right_accuracy = sn.accuracy_check(subject_ids, SFS_check_right, 'S_front_sup')

# %%
SFS_left_accuracy
# Out:
# ({103212: 1,
#   103414: 1,
#   103818: 1,
#   104416: 1,
#   104820: 1,
#   105014: 1,
#   105115: 1,
#   106016: 1,
#   106521: 1,
#   107018: 1,
#   107321: 1,
#   108525: 1,
#   108828: 1,
#   110411: 1,
#   111312: 1,
#   113215: 1,
#   114419: 1,
#   114924: 2,
#   118124: 1,
#   121618: 1,
#   122317: 1,
#   123117: 1,
#   124826: 1,
#   125424: 2,
#   127832: 1,
#   127933: 1,
#   131823: 1,
#   133625: 1,
#   134021: 1,
#   135528: 1,
#   136227: 1,
#   136833: 1,
#   145531: 1,
#   145632: 1,
#   146533: 1,
#   148133: 1,
#   151425: 1,
#   151526: 1,
#   151930: 1,
#   152427: 1,
#   152831: 1,
#   153025: 1,
#   153429: 1,
#   153833: 1,
#   154431: 1,
#   154532: 1,
#   154734: 1,
#   154835: 1,
#   155231: 1,
#   155938: 1,
#   157336: 1,
#   158136: 1,
#   161327: 1,
#   162026: 1,
#   162329: 1,
#   163129: 1,
#   165032: 1,
#   167238: 1,
#   167743: 1,
#   169141: 1,
#   171431: 1,
#   172332: 1,
#   173940: 1,
#   175237: 1,
#   176037: 1,
#   176744: 1,
# ...

# %%
SFS_right_accuracy
# Out:
# ({104012: 1,
#   108121: 1,
#   111312: 1,
#   113619: 2,
#   115017: 1,
#   121618: 1,
#   127630: 1,
#   131419: 1,
#   131621: 1,
#   131924: 1,
#   134021: 1,
#   135225: 1,
#   135528: 1,
#   142424: 1,
#   143325: 1,
#   144226: 1,
#   148133: 1,
#   151526: 1,
#   151930: 1,
#   153126: 1,
#   154835: 1,
#   154936: 1,
#   156233: 1,
#   158843: 1,
#   162026: 1,
#   167743: 1,
#   168947: 1,
#   169343: 1,
#   171431: 1,
#   172534: 1,
#   175237: 1,
#   175439: 1,
#   177746: 1,
#   178849: 2,
#   180129: 1,
#   191942: 2,
#   192843: 1,
#   197449: 1,
#   198249: 2,
#   199150: 1,
#   199251: 1,
#   199655: 3,
#   207123: 1,
#   207426: 1,
#   209834: 1,
#   209935: 1,
#   210617: 1,
#   211114: 1,
#   211922: 1,
#   212116: 1,
#   214019: 1,
#   214726: 1,
#   224022: 1,
#   251833: 1,
#   268850: 1,
#   285446: 1,
#   304020: 1,
#   329440: 1,
#   329844: 1,
#   333330: 1,
#   334635: 1,
#   349244: 1,
#   352132: 1,
#   352738: 1,
#   355542: 1,
#   356948: 1,
# ...

# %% [markdown]
# ### Calcarine Sulcus

# %%
Calcarine_check_left = sn.calcarine_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
Calcarine_check_right = sn.calcarine_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
Calcarine_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, Calcarine_check_left, 'Calcarine_sulcus', 'S_calcarine')
Calcarine_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, Calcarine_check_right, 'Calcarine_sulcus', 'S_calcarine')

# %%
print(Calcarine_prob_left, Calcarine_prob_right)
# Out:
# (28, 572, 0.04895104895104895) (26, 572, 0.045454545454545456)

# %%
Calcarine_left_accuracy = sn.accuracy_check(subject_ids, Calcarine_check_left, 'S_calcarine')
Calcarine_right_accuracy = sn.accuracy_check(subject_ids, Calcarine_check_right, 'S_calcarine')

# %%
Calcarine_left_accuracy
# Out:
# ({103515: 2,
#   106016: 2,
#   108525: 1,
#   114924: 1,
#   124826: 3,
#   131419: 2,
#   134324: 1,
#   152831: 1,
#   154734: 2,
#   158843: 2,
#   182840: 2,
#   336841: 2,
#   355542: 3,
#   356948: 3,
#   371843: 1,
#   441939: 2,
#   485757: 2,
#   541943: 3,
#   573249: 2,
#   592455: 2,
#   679770: 1,
#   705341: 3,
#   742549: 1,
#   774663: 1,
#   870861: 3,
#   930449: 2,
#   958976: 1,
#   994273: 2},
#  9,
#  0.32142857142857145)

# %%
Calcarine_right_accuracy
# Out:
# ({113215: 1,
#   114924: 1,
#   115017: 1,
#   118124: 2,
#   131419: 2,
#   150524: 1,
#   152831: 1,
#   158540: 2,
#   167743: 1,
#   171633: 1,
#   173738: 1,
#   181131: 3,
#   185139: 3,
#   197550: 1,
#   255639: 2,
#   339847: 2,
#   355542: 2,
#   536647: 1,
#   566454: 1,
#   679770: 1,
#   729557: 2,
#   748662: 1,
#   774663: 1,
#   898176: 2,
#   899885: 1,
#   930449: 2},
#  15,
#  0.5769230769230769)

# %% [markdown]
# ### Postcentral Sulcus

# %%
Postcentral_check_left = sn.postcentral_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
Postcentral_check_right = sn.postcentral_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
Postcentral_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, Postcentral_check_left, 'Postcentral_sulcus', 'S_postcentral')
Postcentral_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, Postcentral_check_right, 'Postcentral_sulcus', 'S_postcentral')

# %%
print(Postcentral_prob_left, Postcentral_prob_right)
# Out:
# (413, 572, 0.722027972027972) (340, 572, 0.5944055944055944)

# %%
PoCS_left_accuracy = sn.accuracy_check(subject_ids, Postcentral_check_left, 'S_postcentral')
PoCS_right_accuracy = sn.accuracy_check(subject_ids, Postcentral_check_right, 'S_postcentral')

# %%
PoCS_left_accuracy
# Out:
# ({102816: 6,
#   103111: 5,
#   103414: 6,
#   103818: 6,
#   104416: 6,
#   104820: 5,
#   105115: 5,
#   105216: 5,
#   105620: 5,
#   106319: 6,
#   106521: 4,
#   107018: 5,
#   107321: 7,
#   108121: 4,
#   108525: 6,
#   109123: 4,
#   109325: 6,
#   110411: 5,
#   111009: 7,
#   111312: 6,
#   111716: 6,
#   112112: 4,
#   112819: 6,
#   113215: 6,
#   113619: 6,
#   113922: 5,
#   114419: 6,
#   114924: 2,
#   115320: 5,
#   116120: 6,
#   116524: 5,
#   117930: 5,
#   118124: 6,
#   118225: 5,
#   120717: 6,
#   121315: 6,
#   121416: 6,
#   122317: 6,
#   122620: 5,
#   122822: 5,
#   123117: 4,
#   123420: 5,
#   123925: 6,
#   124422: 6,
#   124826: 6,
#   125424: 5,
#   125525: 6,
#   126931: 6,
#   127630: 5,
#   127832: 6,
#   127933: 6,
#   130619: 5,
#   130922: 5,
#   131217: 5,
#   131419: 6,
#   131621: 5,
#   131722: 6,
#   131823: 5,
#   133625: 5,
#   133827: 5,
#   133928: 4,
#   134021: 5,
#   135124: 6,
#   136227: 4,
#   136833: 4,
#   137027: 6,
# ...

# %%
PoCS_right_accuracy
# Out:
# ({103111: 4,
#   103212: 4,
#   103414: 5,
#   103515: 4,
#   103818: 3,
#   105014: 5,
#   105115: 6,
#   105620: 5,
#   106319: 6,
#   106521: 5,
#   107018: 4,
#   107321: 5,
#   108121: 5,
#   108323: 2,
#   108525: 5,
#   109123: 4,
#   109325: 6,
#   111716: 6,
#   112819: 5,
#   113215: 5,
#   113619: 6,
#   113821: 5,
#   114419: 4,
#   116524: 4,
#   117930: 3,
#   118124: 4,
#   120717: 6,
#   121315: 4,
#   121618: 4,
#   123420: 6,
#   123925: 5,
#   124826: 5,
#   125424: 6,
#   125525: 4,
#   126931: 5,
#   127630: 5,
#   127832: 8,
#   127933: 6,
#   130619: 4,
#   131419: 6,
#   131722: 6,
#   131823: 4,
#   132118: 4,
#   133019: 6,
#   133827: 6,
#   133928: 2,
#   135124: 6,
#   135528: 6,
#   135932: 6,
#   136833: 5,
#   137027: 5,
#   137431: 5,
#   138534: 4,
#   139435: 4,
#   140925: 7,
#   141826: 6,
#   142424: 4,
#   143325: 4,
#   144226: 3,
#   145632: 3,
#   146533: 5,
#   148133: 5,
#   148941: 4,
#   150524: 6,
#   151223: 4,
#   151425: 6,
# ...

# %% [markdown]
# ### Inferior Frontal Sulcus

# %%
IFS_check_left = sn.ifs_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
IFS_check_right = sn.ifs_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
IFS_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, IFS_check_left, 'Inferior_frontal_sulcus', 'S_front_inf')
IFS_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, IFS_check_right, 'Inferior_frontal_sulcus', 'S_front_inf')

# %%
print(IFS_prob_left, IFS_prob_right)
# Out:
# (450, 572, 0.7867132867132867) (490, 572, 0.8566433566433567)

# %%
IFS_left_accuracy = sn.accuracy_check(subject_ids, IFS_check_left, 'S_front_inf')
IFS_right_accuracy = sn.accuracy_check(subject_ids, IFS_check_right, 'S_front_inf')

# %%
IFS_left_accuracy
# Out:
# ({102715: 11,
#   103111: 10,
#   103212: 8,
#   103414: 9,
#   103515: 8,
#   103818: 9,
#   104416: 9,
#   104820: 8,
#   105014: 8,
#   105115: 8,
#   105216: 10,
#   105620: 10,
#   106016: 9,
#   106319: 8,
#   106521: 10,
#   107018: 9,
#   107321: 8,
#   107422: 8,
#   108121: 10,
#   108323: 9,
#   108525: 9,
#   108828: 10,
#   109325: 9,
#   110411: 9,
#   111312: 9,
#   111413: 8,
#   111716: 9,
#   112112: 10,
#   112819: 7,
#   113215: 9,
#   113619: 8,
#   113821: 9,
#   114419: 9,
#   114924: 9,
#   115017: 9,
#   115320: 10,
#   116120: 8,
#   116524: 9,
#   117122: 8,
#   117324: 8,
#   117930: 10,
#   118124: 8,
#   120717: 8,
#   121416: 8,
#   121618: 9,
#   122317: 8,
#   122822: 8,
#   123117: 9,
#   123925: 7,
#   124220: 10,
#   124422: 8,
#   124826: 8,
#   125222: 9,
#   125424: 9,
#   125525: 9,
#   126931: 8,
#   127630: 8,
#   127832: 7,
#   130619: 9,
#   131217: 7,
#   131419: 9,
#   131621: 9,
#   131722: 9,
#   131823: 7,
#   131924: 9,
# ...

# %%
IFS_right_accuracy
# Out:
# ({102715: 10,
#   102816: 8,
#   103111: 9,
#   103212: 8,
#   103414: 9,
#   103515: 8,
#   104012: 9,
#   104416: 9,
#   104820: 8,
#   105014: 9,
#   105115: 8,
#   105216: 7,
#   105620: 10,
#   106319: 10,
#   106521: 10,
#   107321: 8,
#   107422: 8,
#   108121: 8,
#   108323: 7,
#   108525: 8,
#   108828: 10,
#   109123: 9,
#   109325: 9,
#   110411: 10,
#   111009: 8,
#   111312: 8,
#   111413: 9,
#   112112: 8,
#   112819: 8,
#   113215: 8,
#   113619: 10,
#   113821: 7,
#   114419: 10,
#   114924: 9,
#   115017: 8,
#   115320: 9,
#   117930: 9,
#   118124: 10,
#   118225: 9,
#   120717: 9,
#   121315: 9,
#   121416: 8,
#   121618: 8,
#   122317: 10,
#   122822: 9,
#   123117: 9,
#   123420: 8,
#   123925: 8,
#   125222: 9,
#   125525: 8,
#   126931: 9,
#   127630: 10,
#   127832: 8,
#   127933: 9,
#   131419: 8,
#   131621: 10,
#   131823: 8,
#   131924: 8,
#   132118: 10,
#   133019: 8,
#   133625: 10,
#   133827: 9,
#   134021: 7,
#   134324: 8,
#   134728: 9,
# ...

# %% [markdown]
# ### Pericallosal Sulcus

# %%
Pericallosal_check_left = sn.pericallosal_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
Pericallosal_check_right = sn.pericallosal_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
Pericallosal_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, Pericallosal_check_left, 'Pericallosal_sulcus', 'S_pericallosal')
Pericallosal_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, Pericallosal_check_right, 'Pericallosal_sulcus', 'S_pericallosal')

# %%
print(Pericallosal_prob_left, Pericallosal_prob_right)
# Out:
# (15, 572, 0.026223776223776224) (1, 572, 0.0017482517482517483)

# %%
Pericallosal_left_accuracy = sn.accuracy_check(subject_ids, Pericallosal_check_left, 'S_pericallosal')
Pericallosal_right_accuracy = sn.accuracy_check(subject_ids, Pericallosal_check_right, 'S_pericallosal')

# %%
Pericallosal_left_accuracy
# Out:
# ({108525: 3,
#   135528: 3,
#   145632: 4,
#   154431: 4,
#   207426: 3,
#   217126: 3,
#   236130: 5,
#   257542: 5,
#   355239: 3,
#   568963: 5,
#   585862: 2,
#   671855: 2,
#   705341: 5,
#   782157: 5,
#   994273: 2},
#  0,
#  0.0)

# %%
Pericallosal_right_accuracy
# Out:
# ({715041: 9}, 0, 0.0)

# %% [markdown]
# ### Lateral Occipit(o-Temporal) Sulcus

# %%
LOS_check_left = sn.los_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
LOS_check_right = sn.los_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
LOS_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, LOS_check_left, 'Lateral_occipito-temporal_sulcus', 'S_oc-temp_lat')
LOS_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, LOS_check_right, 'Lateral_occipito-temporal_sulcus', 'S_oc-temp_lat')

# %%
print(LOS_prob_left, LOS_prob_right)
# Out:
# (572, 572, 1.0) (572, 572, 1.0)

# %%
LOS_left_accuracy = sn.accuracy_check(subject_ids, LOS_check_left, 'S_oc-temp_lat')
LOS_right_accuracy = sn.accuracy_check(subject_ids, LOS_check_right, 'S_oc-temp_lat')

# %%
LOS_left_accuracy
# Out:
# ({102715: 5,
#   102816: 4,
#   103111: 4,
#   103212: 3,
#   103414: 5,
#   103515: 6,
#   103818: 5,
#   104012: 5,
#   104416: 6,
#   104820: 5,
#   105014: 5,
#   105115: 5,
#   105216: 5,
#   105620: 5,
#   106016: 5,
#   106319: 4,
#   106521: 5,
#   107018: 4,
#   107321: 4,
#   107422: 5,
#   108121: 3,
#   108323: 5,
#   108525: 5,
#   108828: 5,
#   109123: 5,
#   109325: 5,
#   110411: 4,
#   111009: 5,
#   111312: 5,
#   111413: 5,
#   111716: 6,
#   112112: 4,
#   112819: 5,
#   113215: 5,
#   113619: 5,
#   113821: 6,
#   113922: 5,
#   114419: 5,
#   114924: 7,
#   115017: 5,
#   115320: 6,
#   116120: 5,
#   116524: 5,
#   117122: 5,
#   117324: 5,
#   117930: 6,
#   118124: 4,
#   118225: 3,
#   120717: 6,
#   121315: 6,
#   121416: 4,
#   121618: 6,
#   122317: 5,
#   122620: 4,
#   122822: 5,
#   123117: 6,
#   123420: 6,
#   123925: 5,
#   124220: 4,
#   124422: 5,
#   124826: 7,
#   125222: 5,
#   125424: 6,
#   125525: 4,
#   126931: 5,
#   127630: 5,
# ...

# %%
LOS_right_accuracy
# Out:
# ({102715: 5,
#   102816: 5,
#   103111: 5,
#   103212: 5,
#   103414: 5,
#   103515: 5,
#   103818: 5,
#   104012: 6,
#   104416: 5,
#   104820: 5,
#   105014: 4,
#   105115: 4,
#   105216: 4,
#   105620: 5,
#   106016: 5,
#   106319: 5,
#   106521: 5,
#   107018: 6,
#   107321: 5,
#   107422: 5,
#   108121: 6,
#   108323: 5,
#   108525: 6,
#   108828: 6,
#   109123: 6,
#   109325: 6,
#   110411: 6,
#   111009: 5,
#   111312: 8,
#   111413: 5,
#   111716: 5,
#   112112: 6,
#   112819: 4,
#   113215: 5,
#   113619: 4,
#   113821: 4,
#   113922: 4,
#   114419: 4,
#   114924: 7,
#   115017: 5,
#   115320: 6,
#   116120: 6,
#   116524: 6,
#   117122: 5,
#   117324: 5,
#   117930: 5,
#   118124: 5,
#   118225: 5,
#   120717: 5,
#   121315: 6,
#   121416: 3,
#   121618: 3,
#   122317: 2,
#   122620: 4,
#   122822: 4,
#   123117: 5,
#   123420: 5,
#   123925: 6,
#   124220: 3,
#   124422: 5,
#   124826: 6,
#   125222: 4,
#   125424: 5,
#   125525: 6,
#   126931: 5,
#   127630: 4,
# ...

# %% [markdown]
# ### Suborbital Sulcus

# %%
suborbital_check_left = sn.suborbital_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
suborbital_check_right = sn.suborbital_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
suborbital_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, suborbital_check_left, 'Suborbital_sulcus', 'S_suborbital')
suborbital_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, suborbital_check_right, 'Suborbital_sulcus', 'S_suborbital')

# %%
print(suborbital_prob_left, suborbital_prob_right)
# Out:
# (74, 572, 0.12937062937062938) (281, 572, 0.49125874125874125)

# %%
suborbital_left_accuracy = sn.accuracy_check(subject_ids, suborbital_check_left, 'S_suborbital')
suborbital_right_accuracy = sn.accuracy_check(subject_ids, suborbital_check_right, 'S_suborbital')

# %%
suborbital_left_accuracy
# Out:
# ({105620: 5,
#   107422: 4,
#   112112: 5,
#   114924: 3,
#   115017: 3,
#   117930: 5,
#   125525: 4,
#   126931: 5,
#   137431: 4,
#   145531: 6,
#   145632: 6,
#   151223: 4,
#   156031: 5,
#   156637: 4,
#   161327: 4,
#   162329: 4,
#   172938: 6,
#   173435: 6,
#   176037: 4,
#   178748: 5,
#   179548: 2,
#   180129: 4,
#   185442: 4,
#   187547: 4,
#   189450: 3,
#   192843: 6,
#   195041: 5,
#   195849: 6,
#   196144: 5,
#   199958: 5,
#   204521: 5,
#   205725: 6,
#   206222: 7,
#   206525: 5,
#   208024: 4,
#   208226: 3,
#   209329: 6,
#   211114: 5,
#   211215: 4,
#   211316: 4,
#   274542: 6,
#   386250: 4,
#   397861: 4,
#   413934: 5,
#   448347: 4,
#   453441: 3,
#   459453: 2,
#   465852: 4,
#   467351: 4,
#   469961: 4,
#   486759: 4,
#   522434: 5,
#   529953: 5,
#   561242: 4,
#   573249: 4,
#   583858: 6,
#   599671: 6,
#   627549: 5,
#   654754: 4,
#   680452: 5,
#   751348: 5,
#   759869: 5,
#   789373: 6,
#   802844: 3,
#   809252: 7,
#   820745: 4,
# ...

# %%
suborbital_right_accuracy
# Out:
# ({103212: 3,
#   103414: 4,
#   103818: 5,
#   104012: 5,
#   104416: 3,
#   104820: 4,
#   106016: 4,
#   106319: 4,
#   106521: 3,
#   107422: 3,
#   108828: 5,
#   110411: 5,
#   111312: 3,
#   112819: 4,
#   113215: 3,
#   113619: 5,
#   113922: 4,
#   115017: 4,
#   117122: 4,
#   118124: 4,
#   121416: 4,
#   122317: 5,
#   122620: 2,
#   122822: 3,
#   123117: 3,
#   124422: 4,
#   125222: 5,
#   125424: 4,
#   130619: 2,
#   130922: 3,
#   131217: 4,
#   131419: 5,
#   131722: 3,
#   131823: 3,
#   132118: 3,
#   133019: 5,
#   133625: 4,
#   133827: 4,
#   134021: 4,
#   134728: 4,
#   135225: 4,
#   135528: 4,
#   135932: 4,
#   136227: 5,
#   137431: 3,
#   138534: 5,
#   139839: 6,
#   140420: 3,
#   141826: 5,
#   143325: 6,
#   151223: 3,
#   151425: 4,
#   151526: 6,
#   151627: 4,
#   151930: 5,
#   152831: 4,
#   153126: 2,
#   153227: 3,
#   153429: 4,
#   154734: 3,
#   156031: 3,
#   156637: 4,
#   157336: 4,
#   158035: 4,
#   158540: 4,
#   158843: 4,
# ...

# %% [markdown]
# ### Sulcus Intermedius Primus of Jensen

# %%
interm_jen_check_left = sn.interm_jen_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
interm_jen_check_right = sn.interm_jen_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
interm_jen_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, interm_jen_check_left, 'Sulcus_intermedius_primus_of_jensen', 'S_interm_prim-Jensen')
interm_jen_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, interm_jen_check_right, 'Sulcus_intermedius_primus_of_jensen', 'S_interm_prim-Jensen')

# %%
print(interm_jen_prob_left, interm_jen_prob_right)
# Out:
# (278, 572, 0.486013986013986) (9, 572, 0.015734265734265736)

# %%
interm_jen_left_accuracy = sn.accuracy_check(subject_ids, interm_jen_check_left, 'S_interm_prim-Jensen')
interm_jen_right_accuracy = sn.accuracy_check(subject_ids, interm_jen_check_right, 'S_interm_prim-Jensen')

# %%
interm_jen_left_accuracy
# Out:
# ({102816: 2,
#   103111: 2,
#   103212: 1,
#   103515: 1,
#   104416: 2,
#   104820: 2,
#   105014: 1,
#   105115: 2,
#   105620: 1,
#   107321: 2,
#   107422: 1,
#   108121: 1,
#   108323: 1,
#   108828: 1,
#   109325: 2,
#   111009: 1,
#   111312: 1,
#   111413: 2,
#   112112: 1,
#   112819: 1,
#   113215: 1,
#   114419: 2,
#   116120: 2,
#   116524: 1,
#   117122: 2,
#   118124: 2,
#   118225: 2,
#   121315: 2,
#   121416: 2,
#   121618: 1,
#   122317: 2,
#   122822: 1,
#   123925: 2,
#   124220: 1,
#   124422: 1,
#   125525: 2,
#   127630: 2,
#   130922: 1,
#   131419: 2,
#   131722: 1,
#   131823: 2,
#   132118: 2,
#   133827: 1,
#   133928: 2,
#   135124: 1,
#   135225: 1,
#   135932: 2,
#   136833: 1,
#   137431: 2,
#   138534: 2,
#   139839: 2,
#   140925: 1,
#   148133: 2,
#   148941: 1,
#   150524: 1,
#   151425: 1,
#   151627: 1,
#   152831: 1,
#   153025: 1,
#   153126: 2,
#   153227: 2,
#   153429: 1,
#   154431: 2,
#   154532: 1,
#   154835: 1,
#   155231: 2,
# ...

# %%
interm_jen_right_accuracy
# Out:
# ({118225: 1,
#   139839: 1,
#   171633: 1,
#   173435: 1,
#   199453: 1,
#   205725: 1,
#   358144: 1,
#   835657: 1,
#   845458: 2},
#  8,
#  0.8888888888888888)

# %% [markdown]
# ### Occipital Middle and Lunatus Sulcus

# %%
oc_mid_lun_check_left = sn.oc_mid_lun_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
oc_mid_lun_check_right = sn.oc_mid_lun_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
oc_mid_lun_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, oc_mid_lun_check_left, 'Occipital_middle_and_lunatus_sulcus', 'S_oc_middle_and_Lunatus')
oc_mid_lun_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, oc_mid_lun_check_right, 'Occipital_middle_and_lunatus_sulcus', 'S_oc_middle_and_Lunatus')

# %%
print(oc_mid_lun_prob_left, oc_mid_lun_prob_right)
# Out:
# (69, 572, 0.12062937062937062) (57, 572, 0.09965034965034965)

# %%
oc_mid_lun_left_accuracy = sn.accuracy_check(subject_ids, oc_mid_lun_check_left, 'S_oc_middle_and_Lunatus')
oc_mid_lun_right_accuracy = sn.accuracy_check(subject_ids, oc_mid_lun_check_right, 'S_oc_middle_and_Lunatus')

# %%
oc_mid_lun_left_accuracy
# Out:
# ({103515: 3,
#   105014: 2,
#   107422: 3,
#   110411: 2,
#   112819: 2,
#   121618: 3,
#   122620: 1,
#   131217: 1,
#   133928: 1,
#   134728: 2,
#   135225: 1,
#   135528: 2,
#   143325: 4,
#   151425: 2,
#   153227: 2,
#   155635: 2,
#   156031: 2,
#   157437: 2,
#   161327: 2,
#   162026: 3,
#   162228: 4,
#   164131: 3,
#   167743: 2,
#   172332: 4,
#   180432: 1,
#   180836: 1,
#   183034: 1,
#   185139: 4,
#   185442: 2,
#   187143: 2,
#   195041: 3,
#   196952: 3,
#   197550: 3,
#   204016: 2,
#   208327: 2,
#   211114: 2,
#   211821: 3,
#   217126: 2,
#   245333: 1,
#   280739: 3,
#   280941: 2,
#   293748: 3,
#   333330: 2,
#   334635: 2,
#   355239: 3,
#   365343: 3,
#   366446: 1,
#   397861: 3,
#   412528: 2,
#   419239: 3,
#   436845: 4,
#   453441: 3,
#   500222: 2,
#   536647: 2,
#   568963: 3,
#   654754: 3,
#   695768: 1,
#   713239: 3,
#   731140: 4,
#   753251: 2,
#   773257: 3,
#   825048: 2,
#   841349: 3,
#   844961: 1,
#   856766: 1,
#   872158: 3,
# ...

# %%
oc_mid_lun_right_accuracy
# Out:
# ({111716: 2,
#   117122: 2,
#   117324: 2,
#   122822: 2,
#   127630: 2,
#   131217: 1,
#   135932: 2,
#   137431: 3,
#   143325: 2,
#   151223: 1,
#   151930: 2,
#   152427: 2,
#   153227: 1,
#   158540: 4,
#   174437: 1,
#   175439: 1,
#   176542: 2,
#   179346: 3,
#   180129: 2,
#   187143: 2,
#   190031: 1,
#   195041: 1,
#   197550: 1,
#   200311: 2,
#   201111: 1,
#   209329: 4,
#   211215: 2,
#   211821: 1,
#   212419: 2,
#   251833: 2,
#   280739: 3,
#   280941: 2,
#   293748: 2,
#   304020: 1,
#   333330: 1,
#   339847: 3,
#   352738: 1,
#   378756: 1,
#   382242: 3,
#   386250: 2,
#   389357: 3,
#   395251: 2,
#   421226: 2,
#   536647: 3,
#   566454: 1,
#   567961: 2,
#   599469: 1,
#   672756: 1,
#   679568: 3,
#   788674: 1,
#   792766: 1,
#   837560: 2,
#   845458: 3,
#   856766: 2,
#   871964: 1,
#   872158: 3,
#   994273: 1},
#  21,
#  0.3684210526315789)

# %% [markdown]
# ### Superior Occipital Sulcus

# %%
SOS_check_left = sn.sos_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'left')
SOS_check_right = sn.sos_prob_from_formula(subject_ids, All_subject_and_hemisphere_sets, 'right')

# %%
SOS_prob_left = sn.calculating_prob_of_sulcus_found(subject_ids, SOS_check_left, 'Superior_occipital_sulcus', 'S_oc_sup_and_transversal')
SOS_prob_right = sn.calculating_prob_of_sulcus_found(subject_ids, SOS_check_right, 'Superior_occipital_sulcus', 'S_oc_sup_and_transversal')

# %%
print(SOS_prob_left, SOS_prob_right)
# Out:
# (241, 572, 0.42132867132867136) (257, 572, 0.4493006993006993)

# %%
SOS_left_accuracy = sn.accuracy_check(subject_ids, SOS_check_left, 'S_oc_sup_and_transversal')
SOS_right_accuracy = sn.accuracy_check(subject_ids, SOS_check_right, 'S_oc_sup_and_transversal')

# %%
SOS_left_accuracy
# Out:
# ({103111: 1,
#   103212: 1,
#   103414: 1,
#   103818: 1,
#   104012: 1,
#   104820: 2,
#   105216: 1,
#   107018: 1,
#   107321: 1,
#   107422: 2,
#   111009: 2,
#   111312: 2,
#   111716: 2,
#   112112: 1,
#   113215: 1,
#   113619: 2,
#   114419: 1,
#   114924: 1,
#   116524: 2,
#   117122: 1,
#   117324: 2,
#   117930: 1,
#   118124: 1,
#   121618: 1,
#   123117: 1,
#   125424: 1,
#   125525: 2,
#   126931: 2,
#   127933: 1,
#   130922: 1,
#   131621: 1,
#   131722: 1,
#   131823: 1,
#   134324: 1,
#   135528: 1,
#   136833: 1,
#   139435: 1,
#   141826: 2,
#   145531: 1,
#   145632: 1,
#   146533: 1,
#   150625: 2,
#   151728: 1,
#   151930: 1,
#   152427: 2,
#   153227: 1,
#   154431: 1,
#   154734: 2,
#   154835: 2,
#   154936: 2,
#   155231: 2,
#   155635: 2,
#   155938: 1,
#   156233: 1,
#   156637: 2,
#   157336: 1,
#   158843: 1,
#   159239: 1,
#   161327: 1,
#   161630: 1,
#   162026: 2,
#   162329: 2,
#   163129: 1,
#   163331: 1,
#   167238: 1,
#   168341: 1,
# ...

# %%
SOS_right_accuracy
# Out:
# ({102715: 1,
#   103212: 1,
#   103414: 1,
#   104416: 1,
#   105115: 1,
#   105620: 2,
#   106016: 1,
#   106319: 1,
#   106521: 1,
#   107321: 1,
#   107422: 1,
#   108121: 2,
#   109325: 1,
#   111413: 1,
#   112112: 1,
#   113619: 1,
#   113922: 1,
#   114419: 1,
#   114924: 1,
#   115320: 1,
#   116120: 1,
#   116524: 1,
#   117122: 1,
#   117324: 1,
#   117930: 1,
#   118225: 1,
#   121618: 1,
#   122620: 1,
#   123117: 1,
#   123420: 1,
#   123925: 1,
#   125424: 1,
#   125525: 1,
#   126931: 2,
#   127933: 1,
#   131217: 1,
#   131621: 1,
#   131823: 1,
#   132118: 1,
#   133019: 1,
#   133625: 1,
#   133827: 1,
#   133928: 1,
#   134324: 1,
#   135528: 1,
#   136833: 1,
#   137431: 1,
#   138534: 2,
#   140925: 1,
#   141826: 1,
#   143325: 1,
#   148941: 1,
#   150524: 1,
#   150625: 1,
#   151627: 1,
#   152831: 1,
#   153025: 1,
#   153126: 1,
#   153227: 1,
#   153833: 1,
#   154431: 1,
#   154835: 1,
#   154936: 1,
#   155231: 1,
#   156637: 1,
#   157336: 1,
# ...
